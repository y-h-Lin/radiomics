# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab\ Notebooks/radiomics_example
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/radiomics_example

# %% [markdown]
# Import all the lib

# %%
try:
  from radiomics import featureextractor
except ImportError as e:
  # !pip install pyradiomics
  from radiomics import featureextractor

try:
  import nrrd
except ImportError as e:
  # !pip install pynrrd
  import nrrd

import six
import os
import numpy as np
import nibabel as nib
from ipywidgets import *
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Assign the file path

# %%
mask_name   = './crc-segmentation-0.nii'
source_name = './crc-volume-0.nii'

mask = nib.load(mask_name)
mask_array = np.array(mask.dataobj).reshape(mask.shape).transpose(1, 0, 2)

source = nib.load(source_name)
source_array = np.array(source.dataobj).reshape(source.shape).transpose(1, 0, 2)

# %%
(dim_x, dim_y, dim_z) = (source.header['dim'][1:4])
(size_x, size_y, size_z) = (source.header['pixdim'][1:4])
source_max, source_min = np.max(source_array[:,:,:]), np.min(source_array[:,:,:])
mask_max, mask_min = np.max(mask_array[:,:,:]), np.min(mask_array[:,:,:])

# %% [markdown]
# This widget only used for checking data

# %%
def update(slice):    
  src_img = source_array[:,:,slice]
  msk_img = mask_array[:,:,slice]
  fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
  ax[0].imshow(src_img, cmap=plt.cm.gray, vmax=source_max, vmin=source_min)
  ax[1].imshow(msk_img, cmap=plt.cm.hot, vmax=mask_max, vmin=mask_min)
  ax[2].imshow(src_img, cmap=plt.cm.gray, vmax=source_max, vmin=source_min)
  ax[2].imshow(msk_img, cmap=plt.cm.hot, vmax=mask_max, vmin=mask_min, alpha = 0.3)

interact(update, slice = widgets.IntSlider(value=dim_z//2, min=0, max=dim_z-1))
# Out:
# interactive(children=(IntSlider(value=497, description='slice', max=993), Output()), _dom_classes=('widget-int…
# <function __main__.update>

# %%
from skimage.measure import label, regionprops

def extract_bboxes(mask):
  results = []

  label_mask = label(mask)
  for region in regionprops(label_mask):
    x,y,z = np.round(region.centroid).astype(np.int)
    gray = mask[x,y,z]
    label_num = region.label
    minx, miny, minz, maxx, maxy, maxz = region.bbox

    values = (gray, label_num, minx, miny, minz, maxx, maxy, maxz)
    results.append(values)
  
  return results

def crop_volume(source, mask, info):
  (gray, label_num, minx, miny, minz, maxx, maxy, maxz) = info
  msk = mask[minx-1:maxx+1, miny-1:maxy+1, minz-1:maxz+1]
  src = source[minx-1:maxx+1, miny-1:maxy+1, minz-1:maxz+1]
  # msk[msk != gray] = 0
  src[msk != gray] = -1000

  return src, msk

# %% [markdown]
# Get the bounding boxes in 3-D space

# %%
bbox_results = extract_bboxes(mask_array)
print(bbox_results)
# Out:
# [(1, 1, 174, 45, 396, 404, 305, 633), (2, 2, 207, 272, 450, 219, 282, 453), (2, 3, 210, 272, 454, 221, 282, 457), (2, 4, 210, 276, 445, 219, 285, 448), (2, 5, 211, 279, 438, 224, 288, 439), (2, 6, 213, 277, 432, 230, 288, 435), (2, 7, 294, 84, 408, 305, 95, 414), (2, 8, 327, 119, 418, 346, 139, 433)]

# %% [markdown]
# Export the cropped results and execute PyRadiomics

# %%
radiomics_results = []
extractor = featureextractor.RadiomicsFeatureExtractor()

for idx in range(0, len(bbox_results)):  
  # print(bbox_results[idx])
  subRegion, msk = crop_volume(source_array, mask_array, bbox_results[idx])

  # Save NRRD
  img_path_to = './src.nrrd'
  msk_path_to = './msk.nrrd'
  nrrd.write(img_path_to, subRegion)
  nrrd.write(msk_path_to, msk)
 

  radiomics_result = extractor.execute(img_path_to, msk_path_to, voxelBased=False) #maybe you can change the voxelBased to True
  radiomics_results.append(radiomics_result)

  os.remove(img_path_to)
  os.remove(msk_path_to)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %% [markdown]
# Export the results

# %%
for idx in range(len(radiomics_results)):
  radiomics_result = radiomics_results[idx]

  for key, val in six.iteritems(radiomics_result):
    print("\t%s: %s" %(key, val))
# Out:
# 	diagnostics_Versions_PyRadiomics: v3.0.1
# 	diagnostics_Versions_Numpy: 1.19.5
# 	diagnostics_Versions_SimpleITK: 2.0.2
# 	diagnostics_Versions_PyWavelet: 1.1.1
# 	diagnostics_Versions_Python: 3.7.10
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: cba83d50f3e5010eb13ca53b223c333b8b19f861
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (232, 262, 239)
# 	diagnostics_Image-original_Mean: -663.1734090175679
# 	diagnostics_Image-original_Minimum: -1000.0
# 	diagnostics_Image-original_Maximum: 2981.0
# 	diagnostics_Mask-original_Hash: 558a343d8272e3783dc6884d0f4a4279124bd4a8
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (232, 262, 239)
# 	diagnostics_Mask-original_BoundingBox: (1, 1, 1, 230, 260, 237)
# 	diagnostics_Mask-original_VoxelNum: 4419036
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (100.34717187187432, 103.84650385287651, 82.55227859650837)
# 	diagnostics_Mask-original_CenterOfMass: (100.34717187187432, 103.84650385287651, 82.55227859650837)
# 	original_shape_Elongation: 0.7138711603856928
# 	original_shape_Flatness: 0.5922794619056531
# 	original_shape_LeastAxisLength: 152.9895879034323
# 	original_shape_MajorAxisLength: 258.3064207750677
# 	original_shape_Maximum2DDiameterColumn: 240.35390573069537
# 	original_shape_Maximum2DDiameterRow: 279.78027092702587
# 	original_shape_Maximum2DDiameterSlice: 279.5514263959317
# 	original_shape_Maximum3DDiameter: 309.7224564025024
# 	original_shape_MeshVolume: 4418821.541666667
# 	original_shape_MinorAxisLength: 184.39750433377262
# 	original_shape_Sphericity: 0.6180295008000433
# 	original_shape_SurfaceArea: 210707.12761673873
# 	original_shape_SurfaceVolumeRatio: 0.04768400932916276
# 	original_shape_VoxelVolume: 4419036.0
# 	original_firstorder_10Percentile: 87.0
# 	original_firstorder_90Percentile: 128.0
# 	original_firstorder_Energy: 54420478038.0
# 	original_firstorder_Entropy: 1.6772040974941977
# 	original_firstorder_InterquartileRange: 21.0
# 	original_firstorder_Kurtosis: 2384.588412672252
# 	original_firstorder_Maximum: 2981.0
# 	original_firstorder_MeanAbsoluteDeviation: 14.014264132937614
# 	original_firstorder_Mean: 107.30180383232904
# 	original_firstorder_Median: 107.0
# 	original_firstorder_Minimum: -617.0
# 	original_firstorder_Range: 3598.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 8.768152762517426
# 	original_firstorder_RootMeanSquared: 110.97302035334636
# 	original_firstorder_Skewness: 33.088225731965345
# 	original_firstorder_TotalEnergy: 54420478038.0
# 	original_firstorder_Uniformity: 0.39671625241530456
# 	original_firstorder_Variance: 801.3341406726013
# 	original_glcm_Autocorrelation: 890.5333597046343
# 	original_glcm_ClusterProminence: 42936.5500676504
# 	original_glcm_ClusterShade: 288.7874814775947
# 	original_glcm_ClusterTendency: 4.215362067313522
# 	original_glcm_Contrast: 0.8083118090232853
# 	original_glcm_Correlation: 0.6765292885298977
# 	original_glcm_DifferenceAverage: 0.4878909613670064
# 	original_glcm_DifferenceEntropy: 1.169544281411465
# 	original_glcm_DifferenceVariance: 0.5661249325169635
# 	original_glcm_Id: 0.7718763687727239
# 	original_glcm_Idm: 0.7674859397385043
# 	original_glcm_Idmn: 0.999962528011594
# 	original_glcm_Idn: 0.9966709185472135
# 	original_glcm_Imc1: -0.1609024673534094
# 	original_glcm_Imc2: 0.6284415729825454
# 	original_glcm_InverseVariance: 0.41948482076059845
# 	original_glcm_JointAverage: 29.827530653776137
# 	original_glcm_JointEnergy: 0.19300582819169215
# 	original_glcm_JointEntropy: 3.033417124485924
# 	original_glcm_MCC: 0.8414932588999386
# 	original_glcm_MaximumProbability: 0.3663861973579886
# 	original_glcm_SumAverage: 59.65506130755232
# 	original_glcm_SumEntropy: 2.4098510257603794
# 	original_glcm_SumSquares: 1.2559184690842011
# 	original_gldm_DependenceEntropy: 5.838262829898731
# 	original_gldm_DependenceNonUniformity: 220002.8538545511
# 	original_gldm_DependenceNonUniformityNormalized: 0.04978525946712158
# 	original_gldm_DependenceVariance: 30.70019685007304
# 	original_gldm_GrayLevelNonUniformity: 1753103.4012083178
# 	original_gldm_GrayLevelVariance: 1.3638944220646354
# 	original_gldm_HighGrayLevelEmphasis: 890.1814909405581
# 	original_gldm_LargeDependenceEmphasis: 262.1604037622685
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 233809.44123401574
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 0.2944023379704571
# 	original_gldm_LowGrayLevelEmphasis: 0.001128961256004978
# 	original_gldm_SmallDependenceEmphasis: 0.014802876330234952
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 14.049228594846518
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 1.7599526935817834e-05
# 	original_glrlm_GrayLevelNonUniformity: 633186.5240323746
# 	original_glrlm_GrayLevelNonUniformityNormalized: 0.316079990827924
# 	original_glrlm_GrayLevelVariance: 2.4976723894306536
# 	original_glrlm_HighGrayLevelRunEmphasis: 889.4984304756973
# 	original_glrlm_LongRunEmphasis: 8.954459249499457
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 7986.876704951238
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 0.010062161717079805
# 	original_glrlm_LowGrayLevelRunEmphasis: 0.0011339680761213121
# 	original_glrlm_RunEntropy: 4.041037924193399
# 	original_glrlm_RunLengthNonUniformity: 654323.5975321393
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.32134275697316134
# 	original_glrlm_RunPercentage: 0.45331475705770014
# 	original_glrlm_RunVariance: 3.872991796052394
# 	original_glrlm_ShortRunEmphasis: 0.5704862856340394
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 507.6412391015213
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.0006495417192208369
# 	original_glszm_GrayLevelNonUniformity: 11127.85550969872
# 	original_glszm_GrayLevelNonUniformityNormalized: 0.2296297051114057
# 	original_glszm_GrayLevelVariance: 59.72838165135364
# 	original_glszm_HighGrayLevelZoneEmphasis: 978.5163021048287
# 	original_glszm_LargeAreaEmphasis: 155992981.95517954
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 138885363035.7268
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 175355.4924263631
# 	original_glszm_LowGrayLevelZoneEmphasis: 0.001210615546504188
# 	original_glszm_SizeZoneNonUniformity: 11149.78898060256
# 	original_glszm_SizeZoneNonUniformityNormalized: 0.23008231491131984
# 	original_glszm_SmallAreaEmphasis: 0.4877472925024214
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 517.3220918499882
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 0.000618903779040677
# 	original_glszm_ZoneEntropy: 5.913307540209491
# 	original_glszm_ZonePercentage: 0.010966192626627165
# 	original_glszm_ZoneVariance: 155984666.45725352
# 	original_ngtdm_Busyness: 61.662553669590956
# 	original_ngtdm_Coarseness: 1.9640190917726563e-06
# 	original_ngtdm_Complexity: 5096.91618746995
# 	original_ngtdm_Contrast: 5.228375343588294e-05
# 	original_ngtdm_Strength: 0.5817621554612977
# 	diagnostics_Versions_PyRadiomics: v3.0.1
# 	diagnostics_Versions_Numpy: 1.19.5
# 	diagnostics_Versions_SimpleITK: 2.0.2
# 	diagnostics_Versions_PyWavelet: 1.1.1
# 	diagnostics_Versions_Python: 3.7.10
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: a6be6ce24a1aa97e6f87ccd960dfab9dbf6e9449
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (14, 12, 5)
# 	diagnostics_Image-original_Mean: -1000.0
# 	diagnostics_Image-original_Minimum: -1000.0
# 	diagnostics_Image-original_Maximum: -1000.0
# 	diagnostics_Mask-original_Hash: 78eebb53839eeece1e2c7f6fa501dfe24998aa45
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (14, 12, 5)
# 	diagnostics_Mask-original_BoundingBox: (0, 0, 0, 14, 12, 5)
# 	diagnostics_Mask-original_VoxelNum: 568
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (6.123239436619718, 5.419014084507042, 2.0035211267605635)
# 	diagnostics_Mask-original_CenterOfMass: (6.123239436619718, 5.419014084507042, 2.0035211267605635)
# 	original_shape_Elongation: 0.8524105715395393
# 	original_shape_Flatness: 0.3657027158001565
# 	original_shape_LeastAxisLength: 6.495002505717121
# 	original_shape_MajorAxisLength: 17.760334351102845
# 	original_shape_Maximum2DDiameterColumn: 14.560219778561036
# 	original_shape_Maximum2DDiameterRow: 12.649110640673518
# 	original_shape_Maximum2DDiameterSlice: 17.804493814764857
# 	original_shape_Maximum3DDiameter: 18.24828759089466
# 	original_shape_MeshVolume: 563.25
# 	original_shape_MinorAxisLength: 15.139096754956888
# 	original_shape_Sphericity: 0.39314707576106356
# 	original_shape_SurfaceArea: 838.9380167356978
# 	original_shape_SurfaceVolumeRatio: 1.4894594171960902
# 	original_shape_VoxelVolume: 568.0
# 	original_firstorder_10Percentile: -1000.0
# 	original_firstorder_90Percentile: -1000.0
# 	original_firstorder_Energy: 568000000.0
# 	original_firstorder_Entropy: -3.2034265038149176e-16
# 	original_firstorder_InterquartileRange: 0.0
# 	original_firstorder_Kurtosis: 0.0
# 	original_firstorder_Maximum: -1000.0
# 	original_firstorder_MeanAbsoluteDeviation: 0.0
# 	original_firstorder_Mean: -1000.0
# 	original_firstorder_Median: -1000.0
# 	original_firstorder_Minimum: -1000.0
# 	original_firstorder_Range: 0.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 0.0
# 	original_firstorder_RootMeanSquared: 1000.0
# 	original_firstorder_Skewness: 0.0
# 	original_firstorder_TotalEnergy: 568000000.0
# 	original_firstorder_Uniformity: 1.0
# 	original_firstorder_Variance: 0.0
# 	original_glcm_Autocorrelation: 1.0
# 	original_glcm_ClusterProminence: 0.0
# 	original_glcm_ClusterShade: 0.0
# 	original_glcm_ClusterTendency: 0.0
# 	original_glcm_Contrast: 0.0
# 	original_glcm_Correlation: 1.0
# 	original_glcm_DifferenceAverage: 0.0
# 	original_glcm_DifferenceEntropy: -3.203426503814918e-16
# 	original_glcm_DifferenceVariance: 0.0
# 	original_glcm_Id: 1.0
# 	original_glcm_Idm: 1.0
# 	original_glcm_Idmn: 1.0
# 	original_glcm_Idn: 1.0
# 	original_glcm_Imc1: 0.0
# 	original_glcm_Imc2: 0.0
# 	original_glcm_InverseVariance: 0.0
# 	original_glcm_JointAverage: 1.0
# 	original_glcm_JointEnergy: 1.0
# 	original_glcm_JointEntropy: -3.203426503814918e-16
# 	original_glcm_MCC: 1
# 	original_glcm_MaximumProbability: 1.0
# 	original_glcm_SumAverage: 2.0
# 	original_glcm_SumEntropy: -3.203426503814918e-16
# 	original_glcm_SumSquares: 0.0
# 	original_gldm_DependenceEntropy: 3.498299104758995
# 	original_gldm_DependenceNonUniformity: 71.29577464788733
# 	original_gldm_DependenceNonUniformityNormalized: 0.12552073001388614
# 	original_gldm_DependenceVariance: 24.092194009125173
# 	original_gldm_GrayLevelNonUniformity: 568.0
# 	original_gldm_GrayLevelVariance: 0.0
# 	original_gldm_HighGrayLevelEmphasis: 1.0
# 	original_gldm_LargeDependenceEmphasis: 215.7781690140845
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 215.7781690140845
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 215.7781690140845
# 	original_gldm_LowGrayLevelEmphasis: 1.0
# 	original_gldm_SmallDependenceEmphasis: 0.007049908311459798
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 0.007049908311459798
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.007049908311459798
# 	original_glrlm_GrayLevelNonUniformity: 287.38461538461536
# 	original_glrlm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glrlm_GrayLevelVariance: 0.0
# 	original_glrlm_HighGrayLevelRunEmphasis: 1.0
# 	original_glrlm_LongRunEmphasis: 15.346499777416293
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 15.346499777416293
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 15.346499777416293
# 	original_glrlm_LowGrayLevelRunEmphasis: 1.0
# 	original_glrlm_RunEntropy: 1.6619577431171573
# 	original_glrlm_RunLengthNonUniformity: 138.56204861912477
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.43907068385138237
# 	original_glrlm_RunPercentage: 0.5059588299024919
# 	original_glrlm_RunVariance: 6.540633869788345
# 	original_glrlm_ShortRunEmphasis: 0.6408324890114803
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 0.6408324890114803
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.6408324890114803
# 	original_glszm_GrayLevelNonUniformity: 1.0
# 	original_glszm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glszm_GrayLevelVariance: 0.0
# 	original_glszm_HighGrayLevelZoneEmphasis: 1.0
# 	original_glszm_LargeAreaEmphasis: 322624.0
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 322624.0
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 322624.0
# 	original_glszm_LowGrayLevelZoneEmphasis: 1.0
# 	original_glszm_SizeZoneNonUniformity: 1.0
# 	original_glszm_SizeZoneNonUniformityNormalized: 1.0
# 	original_glszm_SmallAreaEmphasis: 3.099583415988891e-06
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 3.099583415988891e-06
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 3.099583415988891e-06
# 	original_glszm_ZoneEntropy: -3.2034265038149176e-16
# 	original_glszm_ZonePercentage: 0.0017605633802816902
# 	original_glszm_ZoneVariance: 0.0
# 	original_ngtdm_Busyness: 0.0
# 	original_ngtdm_Coarseness: 1000000.0
# 	original_ngtdm_Complexity: 0.0
# 	original_ngtdm_Contrast: 0.0
# 	original_ngtdm_Strength: 0.0
# 	diagnostics_Versions_PyRadiomics: v3.0.1
# 	diagnostics_Versions_Numpy: 1.19.5
# 	diagnostics_Versions_SimpleITK: 2.0.2
# 	diagnostics_Versions_PyWavelet: 1.1.1
# 	diagnostics_Versions_Python: 3.7.10
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: cf6fbd77cc1cddf9d1a6abe10c8421d0a342a1df
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (13, 12, 5)
# 	diagnostics_Image-original_Mean: -1000.0
# 	diagnostics_Image-original_Minimum: -1000.0
# 	diagnostics_Image-original_Maximum: -1000.0
# 	diagnostics_Mask-original_Hash: 08e45388e561eb5ba33025f339df46ac67d671d7
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (13, 12, 5)
# 	diagnostics_Mask-original_BoundingBox: (0, 0, 0, 13, 12, 5)
# 	diagnostics_Mask-original_VoxelNum: 530
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (5.820754716981132, 5.549056603773585, 2.009433962264151)
# 	diagnostics_Mask-original_CenterOfMass: (5.820754716981132, 5.549056603773585, 2.009433962264151)
# 	original_shape_Elongation: 0.9217848129562469
# 	original_shape_Flatness: 0.3922620774298156
# 	original_shape_LeastAxisLength: 6.489050756443597
# 	original_shape_MajorAxisLength: 16.54264108057867
# 	original_shape_Maximum2DDiameterColumn: 13.601470508735444
# 	original_shape_Maximum2DDiameterRow: 12.649110640673518
# 	original_shape_Maximum2DDiameterSlice: 17.029386365926403
# 	original_shape_Maximum3DDiameter: 17.4928556845359
# 	original_shape_MeshVolume: 525.4583333333334
# 	original_shape_MinorAxisLength: 15.248755314263533
# 	original_shape_Sphericity: 0.4022309279884816
# 	original_shape_SurfaceArea: 782.8901930560403
# 	original_shape_SurfaceVolumeRatio: 1.4899186926766288
# 	original_shape_VoxelVolume: 530.0
# 	original_firstorder_10Percentile: -1000.0
# 	original_firstorder_90Percentile: -1000.0
# 	original_firstorder_Energy: 530000000.0
# 	original_firstorder_Entropy: -3.2034265038149176e-16
# 	original_firstorder_InterquartileRange: 0.0
# 	original_firstorder_Kurtosis: 0.0
# 	original_firstorder_Maximum: -1000.0
# 	original_firstorder_MeanAbsoluteDeviation: 0.0
# 	original_firstorder_Mean: -1000.0
# 	original_firstorder_Median: -1000.0
# 	original_firstorder_Minimum: -1000.0
# 	original_firstorder_Range: 0.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 0.0
# 	original_firstorder_RootMeanSquared: 1000.0
# 	original_firstorder_Skewness: 0.0
# 	original_firstorder_TotalEnergy: 530000000.0
# 	original_firstorder_Uniformity: 1.0
# 	original_firstorder_Variance: 0.0
# 	original_glcm_Autocorrelation: 1.0
# 	original_glcm_ClusterProminence: 0.0
# 	original_glcm_ClusterShade: 0.0
# 	original_glcm_ClusterTendency: 0.0
# 	original_glcm_Contrast: 0.0
# 	original_glcm_Correlation: 1.0
# 	original_glcm_DifferenceAverage: 0.0
# 	original_glcm_DifferenceEntropy: -3.203426503814918e-16
# 	original_glcm_DifferenceVariance: 0.0
# 	original_glcm_Id: 1.0
# 	original_glcm_Idm: 1.0
# 	original_glcm_Idmn: 1.0
# 	original_glcm_Idn: 1.0
# 	original_glcm_Imc1: 0.0
# 	original_glcm_Imc2: 0.0
# 	original_glcm_InverseVariance: 0.0
# 	original_glcm_JointAverage: 1.0
# 	original_glcm_JointEnergy: 1.0
# 	original_glcm_JointEntropy: -3.203426503814918e-16
# 	original_glcm_MCC: 1
# 	original_glcm_MaximumProbability: 1.0
# 	original_glcm_SumAverage: 2.0
# 	original_glcm_SumEntropy: -3.203426503814918e-16
# 	original_glcm_SumSquares: 0.0
# 	original_gldm_DependenceEntropy: 3.468711042020761
# 	original_gldm_DependenceNonUniformity: 66.16603773584906
# 	original_gldm_DependenceNonUniformityNormalized: 0.12484158063367747
# 	original_gldm_DependenceVariance: 23.324613741545033
# 	original_gldm_GrayLevelNonUniformity: 530.0
# 	original_gldm_GrayLevelVariance: 0.0
# 	original_gldm_HighGrayLevelEmphasis: 1.0
# 	original_gldm_LargeDependenceEmphasis: 214.80754716981133
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 214.80754716981133
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 214.80754716981133
# 	original_gldm_LowGrayLevelEmphasis: 1.0
# 	original_gldm_SmallDependenceEmphasis: 0.006997340813756349
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 0.006997340813756349
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.006997340813756349
# 	original_glrlm_GrayLevelNonUniformity: 268.3076923076923
# 	original_glrlm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glrlm_GrayLevelVariance: 0.0
# 	original_glrlm_HighGrayLevelRunEmphasis: 1.0
# 	original_glrlm_LongRunEmphasis: 14.378181567284772
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 14.378181567284772
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 14.378181567284772
# 	original_glrlm_LowGrayLevelRunEmphasis: 1.0
# 	original_glrlm_RunEntropy: 1.6732626835981166
# 	original_glrlm_RunLengthNonUniformity: 127.63991664416668
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.43425972375705857
# 	original_glrlm_RunPercentage: 0.5062409288824383
# 	original_glrlm_RunVariance: 6.028699218940927
# 	original_glrlm_ShortRunEmphasis: 0.6391396581180548
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 0.6391396581180548
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.6391396581180548
# 	original_glszm_GrayLevelNonUniformity: 1.0
# 	original_glszm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glszm_GrayLevelVariance: 0.0
# 	original_glszm_HighGrayLevelZoneEmphasis: 1.0
# 	original_glszm_LargeAreaEmphasis: 280900.0
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 280900.0
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 280900.0
# 	original_glszm_LowGrayLevelZoneEmphasis: 1.0
# 	original_glszm_SizeZoneNonUniformity: 1.0
# 	original_glszm_SizeZoneNonUniformityNormalized: 1.0
# 	original_glszm_SmallAreaEmphasis: 3.55998576005696e-06
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 3.55998576005696e-06
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 3.55998576005696e-06
# 	original_glszm_ZoneEntropy: -3.2034265038149176e-16
# 	original_glszm_ZonePercentage: 0.0018867924528301887
# 	original_glszm_ZoneVariance: 0.0
# 	original_ngtdm_Busyness: 0.0
# 	original_ngtdm_Coarseness: 1000000.0
# 	original_ngtdm_Complexity: 0.0
# 	original_ngtdm_Contrast: 0.0
# 	original_ngtdm_Strength: 0.0
# 	diagnostics_Versions_PyRadiomics: v3.0.1
# 	diagnostics_Versions_Numpy: 1.19.5
# 	diagnostics_Versions_SimpleITK: 2.0.2
# 	diagnostics_Versions_PyWavelet: 1.1.1
# 	diagnostics_Versions_Python: 3.7.10
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: 1bea753980f523cb3d1ed1d31fc633aef45a07f8
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (11, 11, 5)
# 	diagnostics_Image-original_Mean: -1000.0
# 	diagnostics_Image-original_Minimum: -1000.0
# 	diagnostics_Image-original_Maximum: -1000.0
# 	diagnostics_Mask-original_Hash: c40b67e1d3eb8c096eeb18630aeaf76e4b8911de
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (11, 11, 5)
# 	diagnostics_Mask-original_BoundingBox: (0, 0, 0, 11, 11, 5)
# 	diagnostics_Mask-original_VoxelNum: 460
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (5.010869565217392, 5.126086956521739, 2.0043478260869567)
# 	diagnostics_Mask-original_CenterOfMass: (5.010869565217392, 5.126086956521739, 2.0043478260869567)
# 	original_shape_Elongation: 0.9930322851158772
# 	original_shape_Flatness: 0.45107683474083793
# 	original_shape_LeastAxisLength: 6.222607998372435
# 	original_shape_MajorAxisLength: 13.795006790689168
# 	original_shape_Maximum2DDiameterColumn: 11.704699910719626
# 	original_shape_Maximum2DDiameterRow: 11.704699910719626
# 	original_shape_Maximum2DDiameterSlice: 14.866068747318506
# 	original_shape_Maximum3DDiameter: 15.394804318340652
# 	original_shape_MeshVolume: 455.125
# 	original_shape_MinorAxisLength: 13.698887116547107
# 	original_shape_Sphericity: 0.4763745543817482
# 	original_shape_SurfaceArea: 600.6516811151362
# 	original_shape_SurfaceVolumeRatio: 1.3197510159080168
# 	original_shape_VoxelVolume: 460.0
# 	original_firstorder_10Percentile: -1000.0
# 	original_firstorder_90Percentile: -1000.0
# 	original_firstorder_Energy: 460000000.0
# 	original_firstorder_Entropy: -3.2034265038149176e-16
# 	original_firstorder_InterquartileRange: 0.0
# 	original_firstorder_Kurtosis: 0.0
# 	original_firstorder_Maximum: -1000.0
# 	original_firstorder_MeanAbsoluteDeviation: 0.0
# 	original_firstorder_Mean: -1000.0
# 	original_firstorder_Median: -1000.0
# 	original_firstorder_Minimum: -1000.0
# 	original_firstorder_Range: 0.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 0.0
# 	original_firstorder_RootMeanSquared: 1000.0
# 	original_firstorder_Skewness: 0.0
# 	original_firstorder_TotalEnergy: 460000000.0
# 	original_firstorder_Uniformity: 1.0
# 	original_firstorder_Variance: 0.0
# 	original_glcm_Autocorrelation: 1.0
# 	original_glcm_ClusterProminence: 0.0
# 	original_glcm_ClusterShade: 0.0
# 	original_glcm_ClusterTendency: 0.0
# 	original_glcm_Contrast: 0.0
# 	original_glcm_Correlation: 1.0
# 	original_glcm_DifferenceAverage: 0.0
# 	original_glcm_DifferenceEntropy: -3.203426503814918e-16
# 	original_glcm_DifferenceVariance: 0.0
# 	original_glcm_Id: 1.0
# 	original_glcm_Idm: 1.0
# 	original_glcm_Idmn: 1.0
# 	original_glcm_Idn: 1.0
# 	original_glcm_Imc1: 0.0
# 	original_glcm_Imc2: 0.0
# 	original_glcm_InverseVariance: 0.0
# 	original_glcm_JointAverage: 1.0
# 	original_glcm_JointEnergy: 1.0
# 	original_glcm_JointEntropy: -3.203426503814918e-16
# 	original_glcm_MCC: 1
# 	original_glcm_MaximumProbability: 1.0
# 	original_glcm_SumAverage: 2.0
# 	original_glcm_SumEntropy: -3.203426503814918e-16
# 	original_glcm_SumSquares: 0.0
# 	original_gldm_DependenceEntropy: 3.7152001095358265
# 	original_gldm_DependenceNonUniformity: 45.504347826086956
# 	original_gldm_DependenceNonUniformityNormalized: 0.09892249527410207
# 	original_gldm_DependenceVariance: 21.566654064272207
# 	original_gldm_GrayLevelNonUniformity: 460.0
# 	original_gldm_GrayLevelVariance: 0.0
# 	original_gldm_HighGrayLevelEmphasis: 1.0
# 	original_gldm_LargeDependenceEmphasis: 258.1913043478261
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 258.1913043478261
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 258.1913043478261
# 	original_gldm_LowGrayLevelEmphasis: 1.0
# 	original_gldm_SmallDependenceEmphasis: 0.005546305000475467
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 0.005546305000475467
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.005546305000475467
# 	original_glrlm_GrayLevelNonUniformity: 205.53846153846155
# 	original_glrlm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glrlm_GrayLevelVariance: 0.0
# 	original_glrlm_HighGrayLevelRunEmphasis: 1.0
# 	original_glrlm_LongRunEmphasis: 14.142340981768143
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 14.142340981768143
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 14.142340981768143
# 	original_glrlm_LowGrayLevelRunEmphasis: 1.0
# 	original_glrlm_RunEntropy: 1.8864412648150468
# 	original_glrlm_RunLengthNonUniformity: 74.1642926737605
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.3424225948867281
# 	original_glrlm_RunPercentage: 0.4468227424749164
# 	original_glrlm_RunVariance: 4.772259181315025
# 	original_glrlm_ShortRunEmphasis: 0.5065564978378186
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 0.5065564978378186
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.5065564978378186
# 	original_glszm_GrayLevelNonUniformity: 1.0
# 	original_glszm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glszm_GrayLevelVariance: 0.0
# 	original_glszm_HighGrayLevelZoneEmphasis: 1.0
# 	original_glszm_LargeAreaEmphasis: 211600.0
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 211600.0
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 211600.0
# 	original_glszm_LowGrayLevelZoneEmphasis: 1.0
# 	original_glszm_SizeZoneNonUniformity: 1.0
# 	original_glszm_SizeZoneNonUniformityNormalized: 1.0
# 	original_glszm_SmallAreaEmphasis: 4.7258979206049145e-06
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 4.7258979206049145e-06
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 4.7258979206049145e-06
# 	original_glszm_ZoneEntropy: -3.2034265038149176e-16
# 	original_glszm_ZonePercentage: 0.002173913043478261
# 	original_glszm_ZoneVariance: 0.0
# 	original_ngtdm_Busyness: 0.0
# 	original_ngtdm_Coarseness: 1000000.0
# 	original_ngtdm_Complexity: 0.0
# 	original_ngtdm_Contrast: 0.0
# 	original_ngtdm_Strength: 0.0
# 	diagnostics_Versions_PyRadiomics: v3.0.1
# 	diagnostics_Versions_Numpy: 1.19.5
# 	diagnostics_Versions_SimpleITK: 2.0.2
# 	diagnostics_Versions_PyWavelet: 1.1.1
# 	diagnostics_Versions_Python: 3.7.10
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: 929d70884ad4d6eaa7679dc88e09a6f878c689b4
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (15, 11, 3)
# 	diagnostics_Image-original_Mean: -1000.0
# 	diagnostics_Image-original_Minimum: -1000.0
# 	diagnostics_Image-original_Maximum: -1000.0
# 	diagnostics_Mask-original_Hash: 23a24aa2337fff4c29eb2d0269bfc21901acbf1b
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (15, 11, 3)
# 	diagnostics_Mask-original_BoundingBox: (0, 0, 0, 15, 11, 3)
# 	diagnostics_Mask-original_VoxelNum: 402
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (6.850746268656716, 4.975124378109452, 1.0)
# 	diagnostics_Mask-original_CenterOfMass: (6.850746268656716, 4.975124378109452, 1.0)
# 	original_shape_Elongation: 0.7356008141399659
# 	original_shape_Flatness: 0.20037345998841177
# 	original_shape_LeastAxisLength: 3.624131393618189
# 	original_shape_MajorAxisLength: 18.086883331893276
# 	original_shape_Maximum2DDiameterColumn: 15.132745950421556
# 	original_shape_Maximum2DDiameterRow: 11.180339887498949
# 	original_shape_Maximum2DDiameterSlice: 18.027756377319946
# 	original_shape_Maximum3DDiameter: 18.138357147217054
# 	original_shape_MeshVolume: 397.5
# 	original_shape_MinorAxisLength: 13.304726104195272
# 	original_shape_Sphericity: 0.4003747623675591
# 	original_shape_SurfaceArea: 652.9934914503965
# 	original_shape_SurfaceVolumeRatio: 1.64275092188779
# 	original_shape_VoxelVolume: 402.0
# 	original_firstorder_10Percentile: -1000.0
# 	original_firstorder_90Percentile: -1000.0
# 	original_firstorder_Energy: 402000000.0
# 	original_firstorder_Entropy: -3.2034265038149176e-16
# 	original_firstorder_InterquartileRange: 0.0
# 	original_firstorder_Kurtosis: 0.0
# 	original_firstorder_Maximum: -1000.0
# 	original_firstorder_MeanAbsoluteDeviation: 0.0
# 	original_firstorder_Mean: -1000.0
# 	original_firstorder_Median: -1000.0
# 	original_firstorder_Minimum: -1000.0
# 	original_firstorder_Range: 0.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 0.0
# 	original_firstorder_RootMeanSquared: 1000.0
# 	original_firstorder_Skewness: 0.0
# 	original_firstorder_TotalEnergy: 402000000.0
# 	original_firstorder_Uniformity: 1.0
# 	original_firstorder_Variance: 0.0
# 	original_glcm_Autocorrelation: 1.0
# 	original_glcm_ClusterProminence: 0.0
# 	original_glcm_ClusterShade: 0.0
# 	original_glcm_ClusterTendency: 0.0
# 	original_glcm_Contrast: 0.0
# 	original_glcm_Correlation: 1.0
# 	original_glcm_DifferenceAverage: 0.0
# 	original_glcm_DifferenceEntropy: -3.203426503814918e-16
# 	original_glcm_DifferenceVariance: 0.0
# 	original_glcm_Id: 1.0
# 	original_glcm_Idm: 1.0
# 	original_glcm_Idmn: 1.0
# 	original_glcm_Idn: 1.0
# 	original_glcm_Imc1: 0.0
# 	original_glcm_Imc2: 0.0
# 	original_glcm_InverseVariance: 0.0
# 	original_glcm_JointAverage: 1.0
# 	original_glcm_JointEnergy: 1.0
# 	original_glcm_JointEntropy: -3.203426503814918e-16
# 	original_glcm_MCC: 1
# 	original_glcm_MaximumProbability: 1.0
# 	original_glcm_SumAverage: 2.0
# 	original_glcm_SumEntropy: -3.203426503814918e-16
# 	original_glcm_SumSquares: 0.0
# 	original_gldm_DependenceEntropy: 3.2286284329381068
# 	original_gldm_DependenceNonUniformity: 65.03980099502488
# 	original_gldm_DependenceNonUniformityNormalized: 0.16179054973886786
# 	original_gldm_DependenceVariance: 17.841885101853915
# 	original_gldm_GrayLevelNonUniformity: 402.0
# 	original_gldm_GrayLevelVariance: 0.0
# 	original_gldm_HighGrayLevelEmphasis: 1.0
# 	original_gldm_LargeDependenceEmphasis: 174.40298507462686
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 174.40298507462686
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 174.40298507462686
# 	original_gldm_LowGrayLevelEmphasis: 1.0
# 	original_gldm_SmallDependenceEmphasis: 0.008123389274142193
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 0.008123389274142193
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.008123389274142193
# 	original_glrlm_GrayLevelNonUniformity: 224.0
# 	original_glrlm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glrlm_GrayLevelVariance: 0.0
# 	original_glrlm_HighGrayLevelRunEmphasis: 1.0
# 	original_glrlm_LongRunEmphasis: 21.943763074626183
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 21.943763074626183
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 21.943763074626183
# 	original_glrlm_LowGrayLevelRunEmphasis: 1.0
# 	original_glrlm_RunEntropy: 1.4264135406018994
# 	original_glrlm_RunLengthNonUniformity: 128.08894308991833
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.5040460489524728
# 	original_glrlm_RunPercentage: 0.5572139303482586
# 	original_glrlm_RunVariance: 6.998988005050104
# 	original_glrlm_ShortRunEmphasis: 0.6460894883334011
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 0.6460894883334011
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.6460894883334011
# 	original_glszm_GrayLevelNonUniformity: 1.0
# 	original_glszm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glszm_GrayLevelVariance: 0.0
# 	original_glszm_HighGrayLevelZoneEmphasis: 1.0
# 	original_glszm_LargeAreaEmphasis: 161604.0
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 161604.0
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 161604.0
# 	original_glszm_LowGrayLevelZoneEmphasis: 1.0
# 	original_glszm_SizeZoneNonUniformity: 1.0
# 	original_glszm_SizeZoneNonUniformityNormalized: 1.0
# 	original_glszm_SmallAreaEmphasis: 6.187965644414742e-06
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 6.187965644414742e-06
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 6.187965644414742e-06
# 	original_glszm_ZoneEntropy: -3.2034265038149176e-16
# 	original_glszm_ZonePercentage: 0.0024875621890547263
# 	original_glszm_ZoneVariance: 0.0
# 	original_ngtdm_Busyness: 0.0
# 	original_ngtdm_Coarseness: 1000000.0
# 	original_ngtdm_Complexity: 0.0
# 	original_ngtdm_Contrast: 0.0
# 	original_ngtdm_Strength: 0.0
# 	diagnostics_Versions_PyRadiomics: v3.0.1
# 	diagnostics_Versions_Numpy: 1.19.5
# 	diagnostics_Versions_SimpleITK: 2.0.2
# 	diagnostics_Versions_PyWavelet: 1.1.1
# 	diagnostics_Versions_Python: 3.7.10
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: 40751dcb1319584b44ad1136791a6605dfc8dc36
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (19, 13, 5)
# 	diagnostics_Image-original_Mean: -1000.0
# 	diagnostics_Image-original_Minimum: -1000.0
# 	diagnostics_Image-original_Maximum: -1000.0
# 	diagnostics_Mask-original_Hash: 1537207e8db99d102b8e99712b896565ac60324b
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (19, 13, 5)
# 	diagnostics_Mask-original_BoundingBox: (0, 0, 0, 19, 13, 5)
# 	diagnostics_Mask-original_VoxelNum: 882
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (8.799319727891156, 5.655328798185941, 1.961451247165533)
# 	diagnostics_Mask-original_CenterOfMass: (8.799319727891156, 5.655328798185941, 1.961451247165533)
# 	original_shape_Elongation: 0.680578907213951
# 	original_shape_Flatness: 0.2680355370030892
# 	original_shape_LeastAxisLength: 6.3776516576359565
# 	original_shape_MajorAxisLength: 23.794052568344522
# 	original_shape_Maximum2DDiameterColumn: 19.4164878389476
# 	original_shape_Maximum2DDiameterRow: 13.601470508735444
# 	original_shape_Maximum2DDiameterSlice: 22.47220505424423
# 	original_shape_Maximum3DDiameter: 22.825424421026653
# 	original_shape_MeshVolume: 876.6666666666666
# 	original_shape_MinorAxisLength: 16.193730295155216
# 	original_shape_Sphericity: 0.3873429595172069
# 	original_shape_SurfaceArea: 1143.6104640823633
# 	original_shape_SurfaceVolumeRatio: 1.3044986282308326
# 	original_shape_VoxelVolume: 882.0
# 	original_firstorder_10Percentile: -1000.0
# 	original_firstorder_90Percentile: -1000.0
# 	original_firstorder_Energy: 882000000.0
# 	original_firstorder_Entropy: -3.2034265038149176e-16
# 	original_firstorder_InterquartileRange: 0.0
# 	original_firstorder_Kurtosis: 0.0
# 	original_firstorder_Maximum: -1000.0
# 	original_firstorder_MeanAbsoluteDeviation: 0.0
# 	original_firstorder_Mean: -1000.0
# 	original_firstorder_Median: -1000.0
# 	original_firstorder_Minimum: -1000.0
# 	original_firstorder_Range: 0.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 0.0
# 	original_firstorder_RootMeanSquared: 1000.0
# 	original_firstorder_Skewness: 0.0
# 	original_firstorder_TotalEnergy: 882000000.0
# 	original_firstorder_Uniformity: 1.0
# 	original_firstorder_Variance: 0.0
# 	original_glcm_Autocorrelation: 1.0
# 	original_glcm_ClusterProminence: 0.0
# 	original_glcm_ClusterShade: 0.0
# 	original_glcm_ClusterTendency: 0.0
# 	original_glcm_Contrast: 0.0
# 	original_glcm_Correlation: 1.0
# 	original_glcm_DifferenceAverage: 0.0
# 	original_glcm_DifferenceEntropy: -3.203426503814918e-16
# 	original_glcm_DifferenceVariance: 0.0
# 	original_glcm_Id: 1.0
# 	original_glcm_Idm: 1.0
# 	original_glcm_Idmn: 1.0
# 	original_glcm_Idn: 1.0
# 	original_glcm_Imc1: 0.0
# 	original_glcm_Imc2: 0.0
# 	original_glcm_InverseVariance: 0.0
# 	original_glcm_JointAverage: 1.0
# 	original_glcm_JointEnergy: 1.0
# 	original_glcm_JointEntropy: -3.203426503814918e-16
# 	original_glcm_MCC: 1
# 	original_glcm_MaximumProbability: 1.0
# 	original_glcm_SumAverage: 2.0
# 	original_glcm_SumEntropy: -3.203426503814918e-16
# 	original_glcm_SumSquares: 0.0
# 	original_gldm_DependenceEntropy: 3.572143394307702
# 	original_gldm_DependenceNonUniformity: 103.78911564625851
# 	original_gldm_DependenceNonUniformityNormalized: 0.1176747342928101
# 	original_gldm_DependenceVariance: 29.059836179369704
# 	original_gldm_GrayLevelNonUniformity: 882.0
# 	original_gldm_GrayLevelVariance: 0.0
# 	original_gldm_HighGrayLevelEmphasis: 1.0
# 	original_gldm_LargeDependenceEmphasis: 267.94104308390024
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 267.94104308390024
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 267.94104308390024
# 	original_gldm_LowGrayLevelEmphasis: 1.0
# 	original_gldm_SmallDependenceEmphasis: 0.0059088772990912725
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 0.0059088772990912725
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.0059088772990912725
# 	original_glrlm_GrayLevelNonUniformity: 391.61538461538464
# 	original_glrlm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glrlm_GrayLevelVariance: 0.0
# 	original_glrlm_HighGrayLevelRunEmphasis: 1.0
# 	original_glrlm_LongRunEmphasis: 24.05823895558004
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 24.05823895558004
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 24.05823895558004
# 	original_glrlm_LowGrayLevelRunEmphasis: 1.0
# 	original_glrlm_RunEntropy: 1.965797254720615
# 	original_glrlm_RunLengthNonUniformity: 152.4585377634992
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.34929293005807005
# 	original_glrlm_RunPercentage: 0.4440083725798012
# 	original_glrlm_RunVariance: 9.579340709560416
# 	original_glrlm_ShortRunEmphasis: 0.553092558342155
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 0.553092558342155
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.553092558342155
# 	original_glszm_GrayLevelNonUniformity: 1.0
# 	original_glszm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glszm_GrayLevelVariance: 0.0
# 	original_glszm_HighGrayLevelZoneEmphasis: 1.0
# 	original_glszm_LargeAreaEmphasis: 777924.0
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 777924.0
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 777924.0
# 	original_glszm_LowGrayLevelZoneEmphasis: 1.0
# 	original_glszm_SizeZoneNonUniformity: 1.0
# 	original_glszm_SizeZoneNonUniformityNormalized: 1.0
# 	original_glszm_SmallAreaEmphasis: 1.2854726168623155e-06
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 1.2854726168623155e-06
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 1.2854726168623155e-06
# 	original_glszm_ZoneEntropy: -3.2034265038149176e-16
# 	original_glszm_ZonePercentage: 0.0011337868480725624
# 	original_glszm_ZoneVariance: 0.0
# 	original_ngtdm_Busyness: 0.0
# 	original_ngtdm_Coarseness: 1000000.0
# 	original_ngtdm_Complexity: 0.0
# 	original_ngtdm_Contrast: 0.0
# 	original_ngtdm_Strength: 0.0
# 	diagnostics_Versions_PyRadiomics: v3.0.1
# 	diagnostics_Versions_Numpy: 1.19.5
# 	diagnostics_Versions_SimpleITK: 2.0.2
# 	diagnostics_Versions_PyWavelet: 1.1.1
# 	diagnostics_Versions_Python: 3.7.10
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: fc6726af0240f81b81177977c75bd4d28effc7ad
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (13, 13, 8)
# 	diagnostics_Image-original_Mean: -1000.0
# 	diagnostics_Image-original_Minimum: -1000.0
# 	diagnostics_Image-original_Maximum: -1000.0
# 	diagnostics_Mask-original_Hash: bcf1d20d5600a3afcd3bcd5c2312032b12eaec5d
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (13, 13, 8)
# 	diagnostics_Mask-original_BoundingBox: (0, 0, 0, 13, 13, 8)
# 	diagnostics_Mask-original_VoxelNum: 835
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (5.7149700598802395, 6.107784431137724, 3.9664670658682635)
# 	diagnostics_Mask-original_CenterOfMass: (5.7149700598802395, 6.107784431137724, 3.9664670658682635)
# 	original_shape_Elongation: 0.9692024050668919
# 	original_shape_Flatness: 0.5571454947397507
# 	original_shape_LeastAxisLength: 9.51716314781854
# 	original_shape_MajorAxisLength: 17.082006832459662
# 	original_shape_Maximum2DDiameterColumn: 14.7648230602334
# 	original_shape_Maximum2DDiameterRow: 14.7648230602334
# 	original_shape_Maximum2DDiameterSlice: 17.69180601295413
# 	original_shape_Maximum3DDiameter: 19.026297590440446
# 	original_shape_MeshVolume: 824.0833333333334
# 	original_shape_MinorAxisLength: 16.555922105388987
# 	original_shape_Sphericity: 0.42734005180552775
# 	original_shape_SurfaceArea: 994.6980809313234
# 	original_shape_SurfaceVolumeRatio: 1.2070357944358256
# 	original_shape_VoxelVolume: 835.0
# 	original_firstorder_10Percentile: -1000.0
# 	original_firstorder_90Percentile: -1000.0
# 	original_firstorder_Energy: 835000000.0
# 	original_firstorder_Entropy: -3.2034265038149176e-16
# 	original_firstorder_InterquartileRange: 0.0
# 	original_firstorder_Kurtosis: 0.0
# 	original_firstorder_Maximum: -1000.0
# 	original_firstorder_MeanAbsoluteDeviation: 0.0
# 	original_firstorder_Mean: -1000.0
# 	original_firstorder_Median: -1000.0
# 	original_firstorder_Minimum: -1000.0
# 	original_firstorder_Range: 0.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 0.0
# 	original_firstorder_RootMeanSquared: 1000.0
# 	original_firstorder_Skewness: 0.0
# 	original_firstorder_TotalEnergy: 835000000.0
# 	original_firstorder_Uniformity: 1.0
# 	original_firstorder_Variance: 0.0
# 	original_glcm_Autocorrelation: 1.0
# 	original_glcm_ClusterProminence: 0.0
# 	original_glcm_ClusterShade: 0.0
# 	original_glcm_ClusterTendency: 0.0
# 	original_glcm_Contrast: 0.0
# 	original_glcm_Correlation: 1.0
# 	original_glcm_DifferenceAverage: 0.0
# 	original_glcm_DifferenceEntropy: -3.203426503814918e-16
# 	original_glcm_DifferenceVariance: 0.0
# 	original_glcm_Id: 1.0
# 	original_glcm_Idm: 1.0
# 	original_glcm_Idmn: 1.0
# 	original_glcm_Idn: 1.0
# 	original_glcm_Imc1: 0.0
# 	original_glcm_Imc2: 0.0
# 	original_glcm_InverseVariance: 0.0
# 	original_glcm_JointAverage: 1.0
# 	original_glcm_JointEnergy: 1.0
# 	original_glcm_JointEntropy: -3.203426503814918e-16
# 	original_glcm_MCC: 1
# 	original_glcm_MaximumProbability: 1.0
# 	original_glcm_SumAverage: 2.0
# 	original_glcm_SumEntropy: -3.203426503814918e-16
# 	original_glcm_SumSquares: 0.0
# 	original_gldm_DependenceEntropy: 3.868135033897599
# 	original_gldm_DependenceNonUniformity: 77.33053892215568
# 	original_gldm_DependenceNonUniformityNormalized: 0.09261142385886909
# 	original_gldm_DependenceVariance: 28.83190648642834
# 	original_gldm_GrayLevelNonUniformity: 835.0
# 	original_gldm_GrayLevelVariance: 0.0
# 	original_gldm_HighGrayLevelEmphasis: 1.0
# 	original_gldm_LargeDependenceEmphasis: 301.45748502994013
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 301.45748502994013
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 301.45748502994013
# 	original_gldm_LowGrayLevelEmphasis: 1.0
# 	original_gldm_SmallDependenceEmphasis: 0.005222609890067574
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 0.005222609890067574
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.005222609890067574
# 	original_glrlm_GrayLevelNonUniformity: 336.84615384615387
# 	original_glrlm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glrlm_GrayLevelVariance: 0.0
# 	original_glrlm_HighGrayLevelRunEmphasis: 1.0
# 	original_glrlm_LongRunEmphasis: 14.59209070999399
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 14.59209070999399
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 14.59209070999399
# 	original_glrlm_LowGrayLevelRunEmphasis: 1.0
# 	original_glrlm_RunEntropy: 2.2574776368183986
# 	original_glrlm_RunLengthNonUniformity: 99.82662586947741
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.2771129170163435
# 	original_glrlm_RunPercentage: 0.4034085674804238
# 	original_glrlm_RunVariance: 5.546224737986426
# 	original_glrlm_ShortRunEmphasis: 0.4884963728480057
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 0.4884963728480057
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.4884963728480057
# 	original_glszm_GrayLevelNonUniformity: 1.0
# 	original_glszm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glszm_GrayLevelVariance: 0.0
# 	original_glszm_HighGrayLevelZoneEmphasis: 1.0
# 	original_glszm_LargeAreaEmphasis: 697225.0
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 697225.0
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 697225.0
# 	original_glszm_LowGrayLevelZoneEmphasis: 1.0
# 	original_glszm_SizeZoneNonUniformity: 1.0
# 	original_glszm_SizeZoneNonUniformityNormalized: 1.0
# 	original_glszm_SmallAreaEmphasis: 1.434257234034924e-06
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 1.434257234034924e-06
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 1.434257234034924e-06
# 	original_glszm_ZoneEntropy: -3.2034265038149176e-16
# 	original_glszm_ZonePercentage: 0.0011976047904191617
# 	original_glszm_ZoneVariance: 0.0
# 	original_ngtdm_Busyness: 0.0
# 	original_ngtdm_Coarseness: 1000000.0
# 	original_ngtdm_Complexity: 0.0
# 	original_ngtdm_Contrast: 0.0
# 	original_ngtdm_Strength: 0.0
# 	diagnostics_Versions_PyRadiomics: v3.0.1
# 	diagnostics_Versions_Numpy: 1.19.5
# 	diagnostics_Versions_SimpleITK: 2.0.2
# 	diagnostics_Versions_PyWavelet: 1.1.1
# 	diagnostics_Versions_Python: 3.7.10
# 	diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# 	diagnostics_Configuration_EnabledImageTypes: {'Original': {}}
# 	diagnostics_Image-original_Hash: af8e47fa08aa03d469c60b391c5c8ae443a4da8a
# 	diagnostics_Image-original_Dimensionality: 3D
# 	diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Image-original_Size: (21, 22, 17)
# 	diagnostics_Image-original_Mean: -1000.0
# 	diagnostics_Image-original_Minimum: -1000.0
# 	diagnostics_Image-original_Maximum: -1000.0
# 	diagnostics_Mask-original_Hash: 6f9ea9df270590d0648762f3c236a3fd85a57df5
# 	diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# 	diagnostics_Mask-original_Size: (21, 22, 17)
# 	diagnostics_Mask-original_BoundingBox: (0, 0, 0, 21, 22, 17)
# 	diagnostics_Mask-original_VoxelNum: 5175
# 	diagnostics_Mask-original_VolumeNum: 1
# 	diagnostics_Mask-original_CenterOfMassIndex: (9.344541062801932, 10.617971014492754, 7.72231884057971)
# 	diagnostics_Mask-original_CenterOfMass: (9.344541062801932, 10.617971014492754, 7.72231884057971)
# 	original_shape_Elongation: 0.9098207583618277
# 	original_shape_Flatness: 0.7472920563365943
# 	original_shape_LeastAxisLength: 21.710676106076747
# 	original_shape_MajorAxisLength: 29.052464725113918
# 	original_shape_Maximum2DDiameterColumn: 26.40075756488817
# 	original_shape_Maximum2DDiameterRow: 27.202941017470888
# 	original_shape_Maximum2DDiameterSlice: 29.732137494637012
# 	original_shape_Maximum3DDiameter: 33.76388603226827
# 	original_shape_MeshVolume: 5167.291666666667
# 	original_shape_MinorAxisLength: 26.432535488483392
# 	original_shape_Sphericity: 0.40994896117727114
# 	original_shape_SurfaceArea: 3525.8431207734443
# 	original_shape_SurfaceVolumeRatio: 0.6823387082091896
# 	original_shape_VoxelVolume: 5175.0
# 	original_firstorder_10Percentile: -1000.0
# 	original_firstorder_90Percentile: -1000.0
# 	original_firstorder_Energy: 5175000000.0
# 	original_firstorder_Entropy: -3.2034265038149176e-16
# 	original_firstorder_InterquartileRange: 0.0
# 	original_firstorder_Kurtosis: 0.0
# 	original_firstorder_Maximum: -1000.0
# 	original_firstorder_MeanAbsoluteDeviation: 0.0
# 	original_firstorder_Mean: -1000.0
# 	original_firstorder_Median: -1000.0
# 	original_firstorder_Minimum: -1000.0
# 	original_firstorder_Range: 0.0
# 	original_firstorder_RobustMeanAbsoluteDeviation: 0.0
# 	original_firstorder_RootMeanSquared: 1000.0
# 	original_firstorder_Skewness: 0.0
# 	original_firstorder_TotalEnergy: 5175000000.0
# 	original_firstorder_Uniformity: 1.0
# 	original_firstorder_Variance: 0.0
# 	original_glcm_Autocorrelation: 1.0
# 	original_glcm_ClusterProminence: 0.0
# 	original_glcm_ClusterShade: 0.0
# 	original_glcm_ClusterTendency: 0.0
# 	original_glcm_Contrast: 0.0
# 	original_glcm_Correlation: 1.0
# 	original_glcm_DifferenceAverage: 0.0
# 	original_glcm_DifferenceEntropy: -3.203426503814918e-16
# 	original_glcm_DifferenceVariance: 0.0
# 	original_glcm_Id: 1.0
# 	original_glcm_Idm: 1.0
# 	original_glcm_Idmn: 1.0
# 	original_glcm_Idn: 1.0
# 	original_glcm_Imc1: 0.0
# 	original_glcm_Imc2: 0.0
# 	original_glcm_InverseVariance: 0.0
# 	original_glcm_JointAverage: 1.0
# 	original_glcm_JointEnergy: 1.0
# 	original_glcm_JointEntropy: -3.203426503814918e-16
# 	original_glcm_MCC: 1
# 	original_glcm_MaximumProbability: 1.0
# 	original_glcm_SumAverage: 2.0
# 	original_glcm_SumEntropy: -3.203426503814918e-16
# 	original_glcm_SumSquares: 0.0
# 	original_gldm_DependenceEntropy: 2.9194439219894917
# 	original_gldm_DependenceNonUniformity: 1155.3420289855073
# 	original_gldm_DependenceNonUniformityNormalized: 0.2232544983546874
# 	original_gldm_DependenceVariance: 30.184719363345703
# 	original_gldm_GrayLevelNonUniformity: 5175.0
# 	original_gldm_GrayLevelVariance: 0.0
# 	original_gldm_HighGrayLevelEmphasis: 1.0
# 	original_gldm_LargeDependenceEmphasis: 469.15806763285025
# 	original_gldm_LargeDependenceHighGrayLevelEmphasis: 469.15806763285025
# 	original_gldm_LargeDependenceLowGrayLevelEmphasis: 469.15806763285025
# 	original_gldm_LowGrayLevelEmphasis: 1.0
# 	original_gldm_SmallDependenceEmphasis: 0.003029568192333119
# 	original_gldm_SmallDependenceHighGrayLevelEmphasis: 0.003029568192333119
# 	original_gldm_SmallDependenceLowGrayLevelEmphasis: 0.003029568192333119
# 	original_glrlm_GrayLevelNonUniformity: 1203.8461538461538
# 	original_glrlm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glrlm_GrayLevelVariance: 0.0
# 	original_glrlm_HighGrayLevelRunEmphasis: 1.0
# 	original_glrlm_LongRunEmphasis: 46.04487173229548
# 	original_glrlm_LongRunHighGrayLevelEmphasis: 46.04487173229548
# 	original_glrlm_LongRunLowGrayLevelEmphasis: 46.04487173229548
# 	original_glrlm_LowGrayLevelRunEmphasis: 1.0
# 	original_glrlm_RunEntropy: 3.0715483485819517
# 	original_glrlm_RunLengthNonUniformity: 185.92038686451374
# 	original_glrlm_RunLengthNonUniformityNormalized: 0.15058364783863476
# 	original_glrlm_RunPercentage: 0.2326272761055369
# 	original_glrlm_RunVariance: 18.709613370214665
# 	original_glrlm_ShortRunEmphasis: 0.2887795363609423
# 	original_glrlm_ShortRunHighGrayLevelEmphasis: 0.2887795363609423
# 	original_glrlm_ShortRunLowGrayLevelEmphasis: 0.2887795363609423
# 	original_glszm_GrayLevelNonUniformity: 1.0
# 	original_glszm_GrayLevelNonUniformityNormalized: 1.0
# 	original_glszm_GrayLevelVariance: 0.0
# 	original_glszm_HighGrayLevelZoneEmphasis: 1.0
# 	original_glszm_LargeAreaEmphasis: 26780625.0
# 	original_glszm_LargeAreaHighGrayLevelEmphasis: 26780625.0
# 	original_glszm_LargeAreaLowGrayLevelEmphasis: 26780625.0
# 	original_glszm_LowGrayLevelZoneEmphasis: 1.0
# 	original_glszm_SizeZoneNonUniformity: 1.0
# 	original_glszm_SizeZoneNonUniformityNormalized: 1.0
# 	original_glszm_SmallAreaEmphasis: 3.734042801465612e-08
# 	original_glszm_SmallAreaHighGrayLevelEmphasis: 3.734042801465612e-08
# 	original_glszm_SmallAreaLowGrayLevelEmphasis: 3.734042801465612e-08
# 	original_glszm_ZoneEntropy: -3.2034265038149176e-16
# 	original_glszm_ZonePercentage: 0.0001932367149758454
# 	original_glszm_ZoneVariance: 0.0
# 	original_ngtdm_Busyness: 0.0
# 	original_ngtdm_Coarseness: 1000000.0
# 	original_ngtdm_Complexity: 0.0
# 	original_ngtdm_Contrast: 0.0
# 	original_ngtdm_Strength: 0.0

# %%
def update2(slice):    
  src_img = subRegion[:,:,slice]  
  msk_img = msk[:,:,slice]
  fig2, ax2 = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
  ax2[0].imshow(src_img, cmap=plt.cm.gray, vmax=source_max, vmin=source_min)
  ax2[1].imshow(msk_img, cmap=plt.cm.hot, vmax=mask_max, vmin=mask_min)


interact(update2, slice = widgets.IntSlider(value=np.shape(subRegion)[2]//2, min=0, max=np.shape(subRegion)[2]-1))
# Out:
# interactive(children=(IntSlider(value=8, description='slice', max=16), Output()), _dom_classes=('widget-intera…
# <function __main__.update2>
